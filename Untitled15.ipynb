# %%
# ==============================
# 1. Import Libraries
# ==============================
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# ==============================
# 2. Load MNIST Dataset
# ==============================
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# ==============================
# 3. Data Preprocessing
# ==============================

# Normalize pixel values (0–255 → 0–1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# ==============================
# 4. Build Neural Network Model
# ==============================
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# ==============================
# 5. Compile Model
# ==============================
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ==============================
# 6. Train Model
# ==============================
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)

# ==============================
# 7. Evaluate Model
# ==============================
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)

# ==============================
# 8. Predict Sample Image
# ==============================
import numpy as np

index = 0
prediction = model.predict(X_test[index].reshape(1, 28, 28))
predicted_label = np.argmax(prediction)

plt.imshow(X_test[index], cmap='gray')
plt.title(f"Predicted Digit: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8679 - loss: 0.4700 - val_accuracy: 0.9603 - val_loss: 0.1354
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9637 - loss: 0.1175 - val_accuracy: 0.9653 - val_loss: 0.1053
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9763 - loss: 0.0756 - val_accuracy: 0.9676 - val_loss: 0.1068
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9840 - loss: 0.0529 - val_accuracy: 0.9676 - val_loss: 0.1081
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9870 - loss: 0.0411 - val_accuracy: 0.9722 - val_loss: 0.0965
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9887 - loss: 0.0332 - val_accuracy: 0.9728 - val_loss: 0.1006
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9916 - loss: 0.0257 - val_accuracy: 0.9752 - val_loss: 0.1045
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9927 - loss: 0.0220 - val_accuracy: 0.9751 - val_loss: 0.1034
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9934 - loss: 0.0193 - val_accuracy: 0.9719 - val_loss: 0.1129
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9947 - loss: 0.0153 - val_accuracy: 0.9730 - val_loss: 0.1162
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9719 - loss: 0.1130
# Test Accuracy: 0.9753000140190125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
